# %% [markdown]
# # Especialidad en Estadistica Aplicada
# ## Mateo Orozco Baldovino
#
#
# ## Viernes 13/02/2026
#
# El programa a utilizar sera Alteryx, se puede encontrar en el siguiente link.
#
# https://www.alteryx.com/es/
#
# Esta plataforma se utiliza para realizar los trabajos de Machine Learning sin la utilizacion de codigo. Tiene una version de prueba que se puede utilizar para el analisis de datos.
#
# Tambien se van a utilizar los datos descargados de wine quality de UCI que esta asociada a este link
#
# https://archive.ics.uci.edu/dataset/186/wine+quality
#
# https://archive.ics.uci.edu/dataset/555/apartment+for+rent+classified
#
#
# Despues intentamos utilizar
#
# https://docs.profiling.ydata.ai/latest/

# %% [markdown]
# # Sabado 14/02/2026
#
# El dia de hoy se va a trabajar como crear los modelos de Machine Learning automaticamente
#
# 1. Datos
#
# ¿Problema? ¿Contexto? ¿Cual es el problema que quieres resolver?
# Es el planteamiento del problema. Pensarte que quieres hacer con los datos
#
# 2. Data Preparation
#
# ¿Tiene datos faltantes?
# Tomar decision sobre datos faltantes (Eliminar o imputar datos)
#
# 3. Model Selection
#
# Tengo que seleccionar:
# - Dummy, OLS (Ordinary Least Square)
# - Class of regression
#
# 4. Train
#
# Se tiene que hacer un split de los datos
#
# - Particion Train 60 - 80
# - Particion Validation alrededor de 40
# - Particion test alrededor del 20
#
# 5. Evaluate
#
# 6. Hiperparameter Tuning
#
# 7. Make Predictions

# %% [markdown]
# # 2. Data Preparation
#
# - Verificar si tiene datos faltantes
# - Verificar si tiene outliers
#
# Para hacer predicciones sobre los datos de describe puedo analizar los datos mediante un intervalo de confianza y verificar mediante el coeficiente de pearson para analizar si es correcto.
#
# Si es <0.2 es significativo
# Si es >0.2 no es significativo

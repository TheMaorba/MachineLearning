# %%
import numpy as np
x=np.arange(-30,30,0.5)

# %%
x
# Out:
# array([-30. , -29.5, -29. , -28.5, -28. , -27.5, -27. , -26.5, -26. ,
#        -25.5, -25. , -24.5, -24. , -23.5, -23. , -22.5, -22. , -21.5,
#        -21. , -20.5, -20. , -19.5, -19. , -18.5, -18. , -17.5, -17. ,
#        -16.5, -16. , -15.5, -15. , -14.5, -14. , -13.5, -13. , -12.5,
#        -12. , -11.5, -11. , -10.5, -10. ,  -9.5,  -9. ,  -8.5,  -8. ,
#         -7.5,  -7. ,  -6.5,  -6. ,  -5.5,  -5. ,  -4.5,  -4. ,  -3.5,
#         -3. ,  -2.5,  -2. ,  -1.5,  -1. ,  -0.5,   0. ,   0.5,   1. ,
#          1.5,   2. ,   2.5,   3. ,   3.5,   4. ,   4.5,   5. ,   5.5,
#          6. ,   6.5,   7. ,   7.5,   8. ,   8.5,   9. ,   9.5,  10. ,
#         10.5,  11. ,  11.5,  12. ,  12.5,  13. ,  13.5,  14. ,  14.5,
#         15. ,  15.5,  16. ,  16.5,  17. ,  17.5,  18. ,  18.5,  19. ,
#         19.5,  20. ,  20.5,  21. ,  21.5,  22. ,  22.5,  23. ,  23.5,
#         24. ,  24.5,  25. ,  25.5,  26. ,  26.5,  27. ,  27.5,  28. ,
#         28.5,  29. ,  29.5])

# %%
y1=4*x+6
ruido=np.random.rand(len(x))
y1=y1+ruido

# %%
y1
# Out:
# array([-1.13839404e+02, -1.11675197e+02, -1.09756346e+02, -1.07846590e+02,
#        -1.05253828e+02, -1.03827054e+02, -1.01790148e+02, -9.97617160e+01,
#        -9.77434147e+01, -9.55520990e+01, -9.34368262e+01, -9.10140895e+01,
#        -8.93572862e+01, -8.73882376e+01, -8.51234129e+01, -8.31120033e+01,
#        -8.10496051e+01, -7.95235165e+01, -7.76587086e+01, -7.50651681e+01,
#        -7.37407010e+01, -7.16264119e+01, -6.95597984e+01, -6.77058280e+01,
#        -6.58230949e+01, -6.35216906e+01, -6.18554561e+01, -5.96667218e+01,
#        -5.75704827e+01, -5.51041557e+01, -5.31453442e+01, -5.17532928e+01,
#        -4.92179990e+01, -4.76183010e+01, -4.55515240e+01, -4.36084326e+01,
#        -4.12219871e+01, -3.98081120e+01, -3.78275907e+01, -3.55855328e+01,
#        -3.36443636e+01, -3.14967059e+01, -2.90666738e+01, -2.71745737e+01,
#        -2.51276581e+01, -2.37469756e+01, -2.15918419e+01, -1.96758742e+01,
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x,y1,label="simulado")
plt.scatter(x,y1,label="verdadero")
plt.legend()

# %%
sigma=1/(1+np.exp(-x))

# %%
plt.plot(sigma)
